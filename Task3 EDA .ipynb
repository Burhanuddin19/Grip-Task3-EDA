# %% [markdown]
# ## The Sparks Foundation : Data Science and Bussiness Analytics Intern
# ## Task 3 : Performing EDA on sample dataset 'SampleSuperstore'
# ## By - Burhanuddin

# %% [markdown]
# **Importing Required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing datasets

# %%
#putting r to convert normal string to raw String
df= pd.read_csv(r"C:\Users\Hp\Data science\SampleSuperstore.csv")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head(5)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail(5)
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# #### checking null values are present or not

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data=df.drop_duplicates()
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.shape
# Out:
# (9977, 13)

# %%
data['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
data['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %% [markdown]
# ### 50% of the people belongs to consumer segment
# ### 30% from corporate
# ### 20% from Home office

# %%
data.groupby('Segment').count()['Country']
# Out:
# Segment
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Country, dtype: int64

# %%
ax=(data.groupby('Segment').count()['Country']/data.shape[0])*100
ax
# Out:
# Segment
# Consumer       51.949484
# Corporate      30.219505
# Home Office    17.831011
# Name: Country, dtype: float64

# %%
p=ax.plot(
kind = 'bar',
figsize = (10, 7),
)
p.set_ylabel('Engagement rate %')
# Out:
# Text(0, 0.5, 'Engagement rate %')

# %% [markdown]
# ### As from the category the plot  we understand that the office supplies(60%) are high as compare to furniture nad technology(20%-25%)

# %%
data.groupby('Category').count()['Country']
# Out:
# Category
# Furniture          2118
# Office Supplies    6012
# Technology         1847
# Name: Country, dtype: int64

# %%
bx=(data.groupby('Category').count()['Country']/df.shape[0])*100
bx
# Out:
# Category
# Furniture          21.192716
# Office Supplies    60.156094
# Technology         18.481089
# Name: Country, dtype: float64

# %%
yx=bx.plot(
kind='bar',
    
figsize = (10, 7),
    title = 'Analyzing Category used in thye country'
)
p.set_ylabel('Product rate %')
# Out:
# Text(17.200000000000003, 0.5, 'Product rate %')

# %% [markdown]
# ### As from below the plot the sub-category,category we get the home supplies items are more than the furniture and technology items thats why the sales percentage are high

# %%
cx=(data.groupby(['Category','Sub-Category']).count()['Country']/df.shape[0])
cx
# Out:
# Category         Sub-Category
# Furniture        Bookcases       0.022814
#                  Chairs          0.061537
#                  Furnishings     0.095657
#                  Tables          0.031919
# Office Supplies  Appliances      0.046628
#                  Art             0.079548
#                  Binders         0.152291
#                  Envelopes       0.025415
#                  Fasteners       0.021713
#                  Labels          0.036322
#                  Paper           0.135982
#                  Storage         0.084651
#                  Supplies        0.019011
# Technology       Accessories     0.077547
#                  Copiers         0.006804
#                  Machines        0.011507
#                  Phones          0.088953
# Name: Country, dtype: float64

# %%
cx.unstack()
# Out:
# Sub-Category     Accessories  Appliances       Art   Binders  Bookcases  \
# Category
# Furniture                NaN         NaN       NaN       NaN   0.022814
# Office Supplies          NaN    0.046628  0.079548  0.152291        NaN
# Technology          0.077547         NaN       NaN       NaN        NaN
#
# Sub-Category       Chairs   Copiers  Envelopes  Fasteners  Furnishings  \
# Category
# Furniture        0.061537       NaN        NaN        NaN     0.095657
# Office Supplies       NaN       NaN   0.025415   0.021713          NaN
# Technology            NaN  0.006804        NaN        NaN          NaN
#
# Sub-Category       Labels  Machines     Paper    Phones   Storage  Supplies  \
# Category
# Furniture             NaN       NaN       NaN       NaN       NaN       NaN
# Office Supplies  0.036322       NaN  0.135982       NaN  0.084651  0.019011
# Technology            NaN  0.011507       NaN  0.088953       NaN       NaN
#
# Sub-Category       Tables
# Category
# ...

# %%
dx=cx.unstack().fillna(0)
dx
# Out:
# Sub-Category     Accessories  Appliances       Art   Binders  Bookcases  \
# Category
# Furniture           0.000000    0.000000  0.000000  0.000000   0.022814
# Office Supplies     0.000000    0.046628  0.079548  0.152291   0.000000
# Technology          0.077547    0.000000  0.000000  0.000000   0.000000
#
# Sub-Category       Chairs   Copiers  Envelopes  Fasteners  Furnishings  \
# Category
# Furniture        0.061537  0.000000   0.000000   0.000000     0.095657
# Office Supplies  0.000000  0.000000   0.025415   0.021713     0.000000
# Technology       0.000000  0.006804   0.000000   0.000000     0.000000
#
# Sub-Category       Labels  Machines     Paper    Phones   Storage  Supplies  \
# Category
# Furniture        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Office Supplies  0.036322  0.000000  0.135982  0.000000  0.084651  0.019011
# Technology       0.000000  0.011507  0.000000  0.088953  0.000000  0.000000
#
# Sub-Category       Tables
# Category
# ...

# %%
wx=(dx*100).plot(
kind='bar',
figsize = (15, 10),
    title = 'Analyzing Sub-Category and category used in the country'
)
wx.set_ylabel('Product rate %')
# Out:
# Text(0, 0.5, 'Product rate %')

# %% [markdown]
# ## we check the city which are making profit and which are loss

# %%
plain_profit=data[data['Profit']>=0]
plain_profit
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5     Standard Class   Consumer  United States      Los Angeles  California
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
loss=data[data['Profit']<0]
loss
# Out:
#            Ship Mode      Segment        Country             City  \
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 14    Standard Class  Home Office  United States       Fort Worth
# 15    Standard Class  Home Office  United States       Fort Worth
# 23      Second Class     Consumer  United States     Philadelphia
# 27    Standard Class     Consumer  United States     Philadelphia
# ...              ...          ...            ...              ...
# 9920  Standard Class    Corporate  United States            Bryan
# 9921  Standard Class  Home Office  United States            Akron
# 9931  Standard Class     Consumer  United States   San Bernardino
# 9937    Second Class    Corporate  United States      Los Angeles
# 9962     First Class  Home Office  United States          Houston
#
#              State  Postal Code   Region         Category Sub-Category  \
# 3          Florida        33311    South        Furniture       Tables
# ...

# %% [markdown]
# ### As form the below plot we understamd the sales and profit by category
# #### we are getting more profit in technology as it sales arehigh
# #### we are getting less sales in home office but profit i shigher than the furniture

# %%
ex=data.groupby('Category')['Sales','Profit'].sum()
ex
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                        Sales       Profit
# Category
# Furniture        741306.3133   18421.8137
# Office Supplies  718735.2440  122364.6608
# Technology       836154.0330  145454.9481

# %%
fx=ex.plot(
kind='bar',
figsize = (10, 7),
    title = 'Analyzing Sales and Profit by category '
)
fx.set_ylabel('sales and profit')
# Out:
# Text(0, 0.5, 'sales and profit')

# %%
gx=data.groupby('State')['Sales','Profit'].sum()
gx
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                             Sales      Profit
# State
# Alabama                19510.6400   5786.8253
# Arizona                35282.0010  -3427.9246
# Arkansas               11678.1300   4008.6871
# California            457576.2715  76330.7891
# Colorado               32108.1180  -6527.8579
# Connecticut            13384.3570   3511.4918
# Delaware               27451.0690   9977.3748
# District of Columbia    2865.0200   1059.5893
# Florida                89473.7080  -3399.3017
# Georgia                49095.8400  16250.0433
# Idaho                   4382.4860    826.7231
# Illinois               80162.5370 -12601.6500
# Indiana                53555.3600  18382.9363
# Iowa                    4579.7600   1183.8119
# ...

# %%
hx=gx.plot(
kind='line',
figsize = (10, 7),
    title = 'Analyzing Sales and Profit by State '
)
hx.set_ylabel('sales and profit')
# Out:
# Text(0, 0.5, 'sales and profit')

# %% [markdown]
# **Conclusion- Limiting the sales of products like furnitures as it offers less profit while increasing sales of phones as this category shows both good sales and profit , also states like NewYork, California can give high profits. We also see that more discount ensures higher sales but results in decrease of profit.
